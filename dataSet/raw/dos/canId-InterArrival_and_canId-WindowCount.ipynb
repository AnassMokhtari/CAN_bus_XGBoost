# %% [markdown]
# # DoS Attack Influence on CAN_ID_Inter_Arrival and CAN_ID_Window_Count Analysis
#
# This notebook compares `CAN_ID_Inter_Arrival` and `CAN_ID_Window_Count` between two datasets:
# - **IA_WC_normal.csv**: Normal CAN bus traffic.
# - **IA_WC_dos.csv**: Normal traffic + DoS attack (`CAN_ID = 000`, ~40,000 messages at 4000 messages/s for 10s).
#
# **Goal**: Analyze the DoS attack's impact on `CAN_ID_Inter_Arrival` and `CAN_ID_Window_Count` to enhance detectability.
#
# **Datasets**:
# - **Columns**: `Timestamp` (float), `Interface` (quoted string), `CAN_ID` (quoted string), `Payload` (quoted string), `CAN_ID_Inter_Arrival` (float), `CAN_ID_Window_Count` (integer).
# - **Normal Traffic**: ~386,567 messages over ~275s, `CAN_ID_Inter_Arrival` ~0.001–0.1s (mean ~0.0164s per ID), `CAN_ID_Window_Count` ~1000–3000 per 10s window.
# - **DoS Attack**: Adds ~40,000 `CAN_ID = 000` messages in a 10s window, `CAN_ID_Inter_Arrival` ~0.00025s, `CAN_ID_Window_Count` ~40,000.
# - **CAN_ID_Inter_Arrival**: Time between consecutive messages of the same CAN ID; first message uses mean for that ID (no 0.0 values).
# - **CAN_ID_Window_Count**: Number of messages for a CAN ID in its 10-second window.
#
# **Steps**:
# 1. Load and preprocess datasets (clean quoted strings for `Interface`, `CAN_ID`, `Payload`).
# 2. Compute summary statistics for `CAN_ID_Inter_Arrival` and `CAN_ID_Window_Count`.
# 3. Visualize both parameters (histograms, windowed analysis, box plots).
# 4. Focus on `CAN_ID = 000` for DoS-specific analysis.
# 5. Summarize findings and verify DoS detection using both parameters.

# %%
# Import libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os
import csv

# Set plot style
sns.set_style('whitegrid')
# %matplotlib inline

# Define paths
project_dir = r'C:\Users\pc\OneDrive\Images\Bureau\VS_code_Projects\MLproject_Predictive_Maintenance_for_Vehicles_Using_CAN_Bus_Data'
data_dir = os.path.join(project_dir, 'dataSet', 'raw', 'dos')
plots_dir = os.path.join(project_dir, 'dataSet', 'raw','dos', 'plots')
os.makedirs(plots_dir, exist_ok=True)

normal_file = os.path.join(data_dir, 'IA_WC_normal.csv')
dos_file = os.path.join(data_dir, 'IA_WC_dos.csv')

# %% [markdown]
# ## 1. Load and Preprocess Datasets
#
# Load both CSV files and clean quoted strings (`="..."`) for `Interface`, `CAN_ID`, and `Payload`. `Timestamp` is already a float, and `CAN_ID_Window_Count` is an integer.

# %%
# Load datasets
normal_df = pd.read_csv(normal_file)
dos_df = pd.read_csv(dos_file)

# Clean quoted strings for Interface, CAN_ID, Payload
for col in ['Interface', 'CAN_ID', 'Payload']:
    normal_df[col] = normal_df[col].str.replace('="', '').str.replace('"', '')
    dos_df[col] = dos_df[col].str.replace('="', '').str.replace('"', '')

# Verify columns
expected_columns = ['Timestamp', 'Interface', 'CAN_ID', 'Payload', 'CAN_ID_Inter_Arrival', 'CAN_ID_Window_Count']
if not all(col in normal_df.columns for col in expected_columns):
    print(f"Error: Normal dataset missing columns. Expected: {expected_columns}, Found: {normal_df.columns.tolist()}")
if not all(col in dos_df.columns for col in expected_columns):
    print(f"Error: DoS dataset missing columns. Expected: {expected_columns}, Found: {dos_df.columns.tolist()}")

# Check data types
print("Normal Dataset Data Types:")
print(normal_df.dtypes)
print("\nDoS Dataset Data Types:")
print(dos_df.dtypes)

# Check first few rows
print("\nNormal Dataset Sample:")
print(normal_df.head())
print("\nDoS Dataset Sample:")
print(dos_df.head())
# Out:
# Normal Dataset Data Types:
# Timestamp               float64
# Interface                object
# CAN_ID                   object
# Payload                  object
# CAN_ID_Inter_Arrival    float64
# CAN_ID_Window_Count       int64
# dtype: object
#
# DoS Dataset Data Types:
# Timestamp               float64
# Interface                object
# CAN_ID                   object
# Payload                  object
# CAN_ID_Inter_Arrival    float64
# CAN_ID_Window_Count       int64
# dtype: object
#
# Normal Dataset Sample:
#       Timestamp Interface CAN_ID           Payload  CAN_ID_Inter_Arrival  \
# 0  1.508687e+09    slcan0    12E  C680027FD0FFFF00              0.010000
# 1  1.508687e+09    slcan0    090          1A000000              0.010000
# 2  1.508687e+09    slcan0    0C6  7512800A8008BAAC              0.010000
# 3  1.508687e+09    slcan0    242    0000FFEFFE000D              0.020002
# 4  1.508687e+09    slcan0    29C  00000000FFFFFFFF              0.020001
#
#    CAN_ID_Window_Count
# 0                  611
# 1                  611
# 2                  611
# 3                  306
# 4                  306
#
# DoS Dataset Sample:
#       Timestamp Interface CAN_ID           Payload  CAN_ID_Inter_Arrival  \
# 0  1.508687e+09    slcan0    2C6      FFFFFFFFFFF0              0.022759
# 1  1.508687e+09    slcan0    55D  5119520091C00001              0.111325
# 2  1.508687e+09    slcan0    211    4E2D16BE240000              0.022755
# 3  1.508687e+09    slcan0    214              FBFE              0.022755
# 4  1.508687e+09    slcan0    653          00015800              0.113809
#
#    CAN_ID_Window_Count
# 0                  179
# 1                   36
# 2                  178
# 3                  178
# 4                   36

# %% [markdown]
# ## 2. Summary Statistics
#
# Compute statistics for `CAN_ID_Inter_Arrival` and `CAN_ID_Window_Count`, focusing on `CAN_ID = 000` for DoS detection.

# %%
# Summary statistics for CAN_ID_Inter_Arrival and CAN_ID_Window_Count
stats_data = {}

# Normal Dataset statistics
stats_data['Normal_CAN_ID_Inter_Arrival'] = normal_df['CAN_ID_Inter_Arrival'].describe()
stats_data['Normal_CAN_ID_Window_Count'] = normal_df['CAN_ID_Window_Count'].describe()

# DoS Dataset statistics
stats_data['DoS_CAN_ID_Inter_Arrival'] = dos_df['CAN_ID_Inter_Arrival'].describe()
stats_data['DoS_CAN_ID_Window_Count'] = dos_df['CAN_ID_Window_Count'].describe()

# CAN_ID = 000 statistics
normal_000 = normal_df[normal_df['CAN_ID'] == '000']
dos_000 = dos_df[dos_df['CAN_ID'] == '000']

if not normal_000.empty:
    stats_data['Normal_000_CAN_ID_Inter_Arrival'] = normal_000['CAN_ID_Inter_Arrival'].describe()
    stats_data['Normal_000_CAN_ID_Window_Count'] = normal_000['CAN_ID_Window_Count'].describe()
else:
    stats_data['Normal_000_CAN_ID_Inter_Arrival'] = pd.Series(['No CAN_ID = 000 in normal dataset.'], index=['Note'])
    stats_data['Normal_000_CAN_ID_Window_Count'] = pd.Series(['No CAN_ID = 000 in normal dataset.'], index=['Note'])

if not dos_000.empty:
    stats_data['DoS_000_CAN_ID_Inter_Arrival'] = dos_000['CAN_ID_Inter_Arrival'].describe()
    stats_data['DoS_000_CAN_ID_Window_Count'] = dos_000['CAN_ID_Window_Count'].describe()
else:
    stats_data['DoS_000_CAN_ID_Inter_Arrival'] = pd.Series(['No CAN_ID = 000 in DoS dataset.'], index=['Note'])
    stats_data['DoS_000_CAN_ID_Window_Count'] = pd.Series(['No CAN_ID = 000 in DoS dataset.'], index=['Note'])

# Convert to DataFrame for CSV saving
stats_df = pd.DataFrame(stats_data)

# Save to CSV
stats_df.to_csv(os.path.join(data_dir, 'summary_statistics.csv'))

# Print the statistics
print("Normal Dataset - CAN_ID_Inter_Arrival Statistics:")
print(normal_df['CAN_ID_Inter_Arrival'].describe())
print("\nNormal Dataset - CAN_ID_Window_Count Statistics:")
print(normal_df['CAN_ID_Window_Count'].describe())
print("\nDoS Dataset - CAN_ID_Inter_Arrival Statistics:")
print(dos_df['CAN_ID_Inter_Arrival'].describe())
print("\nDoS Dataset - CAN_ID_Window_Count Statistics:")
print(dos_df['CAN_ID_Window_Count'].describe())

print("\nCAN_ID = 000 - Normal Dataset:")
if not normal_000.empty:
    print("CAN_ID_Inter_Arrival:")
    print(normal_000['CAN_ID_Inter_Arrival'].describe())
    print("CAN_ID_Window_Count:")
    print(normal_000['CAN_ID_Window_Count'].describe())
else:
    print("No CAN_ID = 000 in normal dataset.")
print("\nCAN_ID = 000 - DoS Dataset:")
if not dos_000.empty:
    print("CAN_ID_Inter_Arrival:")
    print(dos_000['CAN_ID_Inter_Arrival'].describe())
    print("CAN_ID_Window_Count:")
    print(dos_000['CAN_ID_Window_Count'].describe())
else:
    print("No CAN_ID = 000 in DoS dataset.")
# Out:
# Normal Dataset - CAN_ID_Inter_Arrival Statistics:
# count    386567.000000
# mean          0.039141
# std           0.084468
# min           0.000025
# 25%           0.010022
# 50%           0.019925
# 75%           0.049586
# max           3.050461
# Name: CAN_ID_Inter_Arrival, dtype: float64
#
# Normal Dataset - CAN_ID_Window_Count Statistics:
# count    386567.000000
# mean        597.383773
# std         369.028652
# min           2.000000
# 25%         200.000000
# 50%         500.000000
# 75%        1000.000000
# max        1001.000000
# Name: CAN_ID_Window_Count, dtype: float64
#
# DoS Dataset - CAN_ID_Inter_Arrival Statistics:
# count    141927.000000
# mean          0.032080
# std           0.212978
# min           0.000037
# 25%           0.000289
# 50%           0.010069
# 75%           0.020096
# max          12.013576
# Name: CAN_ID_Inter_Arrival, dtype: float64
#
# DoS Dataset - CAN_ID_Window_Count Statistics:
# count    141927.000000
# mean       6247.435393
# std        9352.258820
# min           1.000000
# 25%         356.000000
# 50%         899.000000
# 75%       16012.000000
# max       23989.000000
# Name: CAN_ID_Window_Count, dtype: float64
#
# CAN_ID = 000 - Normal Dataset:
# No CAN_ID = 000 in normal dataset.
#
# CAN_ID = 000 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# count    40001.000000
# mean         0.000250
# std          0.000029
# min          0.000200
# 25%          0.000225
# 50%          0.000250
# 75%          0.000275
# max          0.000300
# Name: CAN_ID_Inter_Arrival, dtype: float64
# CAN_ID_Window_Count:
# count    40001.000000
# mean     20795.886728
# std       3908.436272
# min      16012.000000
# 25%      16012.000000
# 50%      23989.000000
# 75%      23989.000000
# max      23989.000000
# Name: CAN_ID_Window_Count, dtype: float64

# %%
# Ensure CAN_ID is treated as a string
normal_df['CAN_ID'] = normal_df['CAN_ID'].astype(str)

# Calculate statistics for each CAN_ID in normal dataset
stats_normal = normal_df.groupby('CAN_ID').agg({
    'CAN_ID_Inter_Arrival': ['min', 'max', 'mean'],
    'CAN_ID_Window_Count': ['min', 'max', 'mean']
})

# Rename columns for clarity
stats_normal.columns = ['_'.join(col).strip() for col in stats_normal.columns.values]

# Reset index to make CAN_ID a column
stats_normal = stats_normal.reset_index()

# Ensure CAN_ID is quoted in CSV to prevent scientific notation
stats_normal['CAN_ID'] = stats_normal['CAN_ID'].apply(lambda x: f'"{x}"')

# Save to CSV with quoting
stats_normal.to_csv(os.path.join(data_dir, 'normal_can_id_statistics.csv'), index=False, quoting=csv.QUOTE_NONNUMERIC)

# Print statistics for each CAN_ID
for can_id in stats_normal.index:
    print(f"\nCAN_ID = {stats_normal.loc[can_id, 'CAN_ID'].strip('\"')} - Normal Dataset:")
    print(f"CAN_ID_Inter_Arrival:")
    print(stats_normal.loc[can_id, ['CAN_ID_Inter_Arrival_min', 'CAN_ID_Inter_Arrival_max', 'CAN_ID_Inter_Arrival_mean']])
    print(f"CAN_ID_Window_Count:")
    print(stats_normal.loc[can_id, ['CAN_ID_Window_Count_min', 'CAN_ID_Window_Count_max', 'CAN_ID_Window_Count_mean']])
# Out:
# CAN_ID = 090 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.000025
# CAN_ID_Inter_Arrival_max     0.024192
# CAN_ID_Inter_Arrival_mean        0.01
# Name: 0, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            611
# CAN_ID_Window_Count_max           1000
# CAN_ID_Window_Count_mean    988.030281
# Name: 0, dtype: object
#
# CAN_ID = 0C6 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.000028
# CAN_ID_Inter_Arrival_max     0.023957
# CAN_ID_Inter_Arrival_mean        0.01
# Name: 1, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            611
# CAN_ID_Window_Count_max           1000
# CAN_ID_Window_Count_mean    988.030281
# Name: 1, dtype: object
#
# CAN_ID = 12E - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.000033
# CAN_ID_Inter_Arrival_max     0.024359
# CAN_ID_Inter_Arrival_mean        0.01
# Name: 2, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            611
# CAN_ID_Window_Count_max           1000
# CAN_ID_Window_Count_mean    988.030281
# Name: 2, dtype: object
#
# CAN_ID = 186 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.000042
# CAN_ID_Inter_Arrival_max     0.024857
# CAN_ID_Inter_Arrival_mean    0.010001
# Name: 3, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            611
# CAN_ID_Window_Count_max           1001
# CAN_ID_Window_Count_mean    987.949576
# Name: 3, dtype: object
#
# CAN_ID = 18A - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.00004
# CAN_ID_Inter_Arrival_max     0.024621
# CAN_ID_Inter_Arrival_mean    0.010001
# Name: 4, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            611
# CAN_ID_Window_Count_max           1001
# CAN_ID_Window_Count_mean    987.949576
# Name: 4, dtype: object
#
# CAN_ID = 1A0 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.091542
# CAN_ID_Inter_Arrival_max      0.20197
# CAN_ID_Inter_Arrival_mean    0.100215
# Name: 5, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            61
# CAN_ID_Window_Count_max           101
# CAN_ID_Window_Count_mean    98.590528
# Name: 5, dtype: object
#
# CAN_ID = 1F6 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.000044
# CAN_ID_Inter_Arrival_max     0.025027
# CAN_ID_Inter_Arrival_mean    0.010001
# Name: 6, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            611
# CAN_ID_Window_Count_max           1001
# CAN_ID_Window_Count_mean    987.949504
# Name: 6, dtype: object
#
# CAN_ID = 211 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.011068
# CAN_ID_Inter_Arrival_max     0.028909
# CAN_ID_Inter_Arrival_mean    0.019998
# Name: 7, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            306
# CAN_ID_Window_Count_max            501
# CAN_ID_Window_Count_mean    494.056412
# Name: 7, dtype: object
#
# CAN_ID = 214 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.011183
# CAN_ID_Inter_Arrival_max     0.039917
# CAN_ID_Inter_Arrival_mean        0.02
# Name: 8, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            306
# CAN_ID_Window_Count_max            501
# CAN_ID_Window_Count_mean    494.019702
# Name: 8, dtype: object
#
# CAN_ID = 217 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.006831
# CAN_ID_Inter_Arrival_max     0.040708
# CAN_ID_Inter_Arrival_mean    0.020003
# Name: 9, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            305
# CAN_ID_Window_Count_max            500
# CAN_ID_Window_Count_mean    493.937464
# Name: 9, dtype: object
#
# CAN_ID = 218 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.091406
# CAN_ID_Inter_Arrival_max     0.199886
# CAN_ID_Inter_Arrival_mean    0.100102
# Name: 10, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min           61
# CAN_ID_Window_Count_max          100
# CAN_ID_Window_Count_mean    98.69869
# Name: 10, dtype: object
#
# CAN_ID = 242 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.006597
# CAN_ID_Inter_Arrival_max     0.040009
# CAN_ID_Inter_Arrival_mean    0.020002
# Name: 11, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            306
# CAN_ID_Window_Count_max            500
# CAN_ID_Window_Count_mean    493.982696
# Name: 11, dtype: object
#
# CAN_ID = 29A - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.006306
# CAN_ID_Inter_Arrival_max     0.033649
# CAN_ID_Inter_Arrival_mean    0.020001
# Name: 12, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            305
# CAN_ID_Window_Count_max            500
# CAN_ID_Window_Count_mean    494.010906
# Name: 12, dtype: object
#
# CAN_ID = 29C - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.007055
# CAN_ID_Inter_Arrival_max     0.033427
# CAN_ID_Inter_Arrival_mean    0.020001
# Name: 13, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            306
# CAN_ID_Window_Count_max            500
# CAN_ID_Window_Count_mean    494.019411
# Name: 13, dtype: object
#
# CAN_ID = 2B7 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.006599
# CAN_ID_Inter_Arrival_max     0.033572
# CAN_ID_Inter_Arrival_mean    0.020001
# Name: 14, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            305
# CAN_ID_Window_Count_max            500
# CAN_ID_Window_Count_mean    494.010906
# Name: 14, dtype: object
#
# CAN_ID = 2C6 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.007265
# CAN_ID_Inter_Arrival_max     0.040714
# CAN_ID_Inter_Arrival_mean    0.020003
# Name: 15, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            305
# CAN_ID_Window_Count_max            500
# CAN_ID_Window_Count_mean    493.937464
# Name: 15, dtype: object
#
# CAN_ID = 303 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.09194
# CAN_ID_Inter_Arrival_max     0.108062
# CAN_ID_Inter_Arrival_mean    0.100017
# Name: 16, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            61
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    98.771636
# Name: 16, dtype: object
#
# CAN_ID = 350 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.008334
# CAN_ID_Inter_Arrival_max     0.108366
# CAN_ID_Inter_Arrival_mean    0.098631
# Name: 17, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min             63
# CAN_ID_Window_Count_max            108
# CAN_ID_Window_Count_mean    100.198279
# Name: 17, dtype: object
#
# CAN_ID = 352 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.032947
# CAN_ID_Inter_Arrival_max      0.04719
# CAN_ID_Inter_Arrival_mean    0.040001
# Name: 18, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            153
# CAN_ID_Window_Count_max            250
# CAN_ID_Window_Count_mean    247.024426
# Name: 18, dtype: object
#
# CAN_ID = 354 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min       0.0272
# CAN_ID_Inter_Arrival_max     0.052704
# CAN_ID_Inter_Arrival_mean    0.040001
# Name: 19, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            153
# CAN_ID_Window_Count_max            250
# CAN_ID_Window_Count_mean    246.995056
# Name: 19, dtype: object
#
# CAN_ID = 392 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.037124
# CAN_ID_Inter_Arrival_max     0.100009
# CAN_ID_Inter_Arrival_mean    0.050013
# Name: 20, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            122
# CAN_ID_Window_Count_max            200
# CAN_ID_Window_Count_mean    197.579531
# Name: 20, dtype: object
#
# CAN_ID = 3B7 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.092244
# CAN_ID_Inter_Arrival_max      0.20244
# CAN_ID_Inter_Arrival_mean    0.100534
# Name: 21, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            61
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    98.266813
# Name: 21, dtype: object
#
# CAN_ID = 3FA - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min        0.092
# CAN_ID_Inter_Arrival_max      0.10799
# CAN_ID_Inter_Arrival_mean    0.100016
# Name: 22, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            61
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    98.771636
# Name: 22, dtype: object
#
# CAN_ID = 433 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.99773
# CAN_ID_Inter_Arrival_max     1.002991
# CAN_ID_Inter_Arrival_mean      1.0004
# Name: 23, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min        6
# CAN_ID_Window_Count_max       10
# CAN_ID_Window_Count_mean    9.88
# Name: 23, dtype: object
#
# CAN_ID = 45C - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.092518
# CAN_ID_Inter_Arrival_max     0.199859
# CAN_ID_Inter_Arrival_mean     0.10003
# Name: 24, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min           62
# CAN_ID_Window_Count_max          101
# CAN_ID_Window_Count_mean    98.78117
# Name: 24, dtype: object
#
# CAN_ID = 4AC - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.009844
# CAN_ID_Inter_Arrival_max     0.203194
# CAN_ID_Inter_Arrival_mean    0.099776
# Name: 25, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            64
# CAN_ID_Window_Count_max           102
# CAN_ID_Window_Count_mean    98.992748
# Name: 25, dtype: object
#
# CAN_ID = 4F8 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.081258
# CAN_ID_Inter_Arrival_max      0.11871
# CAN_ID_Inter_Arrival_mean    0.100497
# Name: 26, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            61
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    98.302886
# Name: 26, dtype: object
#
# CAN_ID = 4FA - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.091599
# CAN_ID_Inter_Arrival_max     0.108325
# CAN_ID_Inter_Arrival_mean    0.099992
# Name: 27, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min           61
# CAN_ID_Window_Count_max          100
# CAN_ID_Window_Count_mean    98.80807
# Name: 27, dtype: object
#
# CAN_ID = 500 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.088416
# CAN_ID_Inter_Arrival_max     0.111943
# CAN_ID_Inter_Arrival_mean    0.100016
# Name: 28, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min           61
# CAN_ID_Window_Count_max          100
# CAN_ID_Window_Count_mean    98.80807
# Name: 28, dtype: object
#
# CAN_ID = 511 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.093071
# CAN_ID_Inter_Arrival_max     0.106944
# CAN_ID_Inter_Arrival_mean    0.100006
# Name: 29, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min           61
# CAN_ID_Window_Count_max          100
# CAN_ID_Window_Count_mean    98.80807
# Name: 29, dtype: object
#
# CAN_ID = 552 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.091708
# CAN_ID_Inter_Arrival_max     0.108347
# CAN_ID_Inter_Arrival_mean    0.100017
# Name: 30, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            61
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    98.771636
# Name: 30, dtype: object
#
# CAN_ID = 55D - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.017555
# CAN_ID_Inter_Arrival_max     0.108235
# CAN_ID_Inter_Arrival_mean    0.097236
# Name: 31, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min             66
# CAN_ID_Window_Count_max            109
# CAN_ID_Window_Count_mean    101.606575
# Name: 31, dtype: object
#
# CAN_ID = 563 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.091662
# CAN_ID_Inter_Arrival_max     0.108219
# CAN_ID_Inter_Arrival_mean     0.09996
# Name: 32, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            61
# CAN_ID_Window_Count_max           101
# CAN_ID_Window_Count_mean    98.845203
# Name: 32, dtype: object
#
# CAN_ID = 564 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.09133
# CAN_ID_Inter_Arrival_max     0.199983
# CAN_ID_Inter_Arrival_mean     0.10005
# Name: 33, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            61
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    98.771636
# Name: 33, dtype: object
#
# CAN_ID = 575 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.092609
# CAN_ID_Inter_Arrival_max     0.107295
# CAN_ID_Inter_Arrival_mean    0.100016
# Name: 34, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            61
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    98.771636
# Name: 34, dtype: object
#
# CAN_ID = 5D7 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.086657
# CAN_ID_Inter_Arrival_max     0.113206
# CAN_ID_Inter_Arrival_mean    0.100003
# Name: 35, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min           61
# CAN_ID_Window_Count_max          100
# CAN_ID_Window_Count_mean    98.80807
# Name: 35, dtype: object
#
# CAN_ID = 5DA - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.093341
# CAN_ID_Inter_Arrival_max     0.106723
# CAN_ID_Inter_Arrival_mean    0.100006
# Name: 36, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min           61
# CAN_ID_Window_Count_max          100
# CAN_ID_Window_Count_mean    98.80807
# Name: 36, dtype: object
#
# CAN_ID = 5DE - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.017276
# CAN_ID_Inter_Arrival_max     0.107542
# CAN_ID_Inter_Arrival_mean    0.096418
# Name: 37, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min             61
# CAN_ID_Window_Count_max            130
# CAN_ID_Window_Count_mean    103.070102
# Name: 37, dtype: object
#
# CAN_ID = 5DF - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.092636
# CAN_ID_Inter_Arrival_max     0.199934
# CAN_ID_Inter_Arrival_mean     0.10003
# Name: 38, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min           62
# CAN_ID_Window_Count_max          101
# CAN_ID_Window_Count_mean    98.78117
# Name: 38, dtype: object
#
# CAN_ID = 5E9 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.086789
# CAN_ID_Inter_Arrival_max     0.113228
# CAN_ID_Inter_Arrival_mean    0.100046
# Name: 39, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            61
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    98.771636
# Name: 39, dtype: object
#
# CAN_ID = 62C - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.093231
# CAN_ID_Inter_Arrival_max     0.200267
# CAN_ID_Inter_Arrival_mean    0.100033
# Name: 40, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            61
# CAN_ID_Window_Count_max           101
# CAN_ID_Window_Count_mean    98.772364
# Name: 40, dtype: object
#
# CAN_ID = 634 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.090611
# CAN_ID_Inter_Arrival_max     0.109506
# CAN_ID_Inter_Arrival_mean    0.100055
# Name: 41, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            61
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    98.735176
# Name: 41, dtype: object
#
# CAN_ID = 646 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.49448
# CAN_ID_Inter_Arrival_max     0.528792
# CAN_ID_Inter_Arrival_mean    0.508487
# Name: 42, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            12
# CAN_ID_Window_Count_max            20
# CAN_ID_Window_Count_mean    19.439926
# Name: 42, dtype: object
#
# CAN_ID = 648 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.093605
# CAN_ID_Inter_Arrival_max      0.10647
# CAN_ID_Inter_Arrival_mean    0.100006
# Name: 43, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min           61
# CAN_ID_Window_Count_max          100
# CAN_ID_Window_Count_mean    98.80807
# Name: 43, dtype: object
#
# CAN_ID = 653 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.081401
# CAN_ID_Inter_Arrival_max     0.118573
# CAN_ID_Inter_Arrival_mean    0.100014
# Name: 44, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min           61
# CAN_ID_Window_Count_max          100
# CAN_ID_Window_Count_mean    98.80807
# Name: 44, dtype: object
#
# CAN_ID = 657 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.089384
# CAN_ID_Inter_Arrival_max     0.110617
# CAN_ID_Inter_Arrival_mean    0.099993
# Name: 45, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min           61
# CAN_ID_Window_Count_max          100
# CAN_ID_Window_Count_mean    98.80807
# Name: 45, dtype: object
#
# CAN_ID = 65C - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.091886
# CAN_ID_Inter_Arrival_max     0.107893
# CAN_ID_Inter_Arrival_mean    0.100006
# Name: 46, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min           61
# CAN_ID_Window_Count_max          100
# CAN_ID_Window_Count_mean    98.80807
# Name: 46, dtype: object
#
# CAN_ID = 665 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     2.998141
# CAN_ID_Inter_Arrival_max     3.004221
# CAN_ID_Inter_Arrival_mean    3.001202
# Name: 47, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            2
# CAN_ID_Window_Count_max            4
# CAN_ID_Window_Count_mean    3.369565
# Name: 47, dtype: object
#
# CAN_ID = 666 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.093531
# CAN_ID_Inter_Arrival_max     0.106428
# CAN_ID_Inter_Arrival_mean    0.100003
# Name: 48, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            61
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    98.778909
# Name: 48, dtype: object
#
# CAN_ID = 66A - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.09285
# CAN_ID_Inter_Arrival_max     0.107159
# CAN_ID_Inter_Arrival_mean    0.100006
# Name: 49, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min           61
# CAN_ID_Window_Count_max          100
# CAN_ID_Window_Count_mean    98.80807
# Name: 49, dtype: object
#
# CAN_ID = 671 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.091828
# CAN_ID_Inter_Arrival_max     0.201838
# CAN_ID_Inter_Arrival_mean    0.100101
# Name: 50, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min           61
# CAN_ID_Window_Count_max          100
# CAN_ID_Window_Count_mean    98.69869
# Name: 50, dtype: object
#
# CAN_ID = 673 - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.094854
# CAN_ID_Inter_Arrival_max     0.105166
# CAN_ID_Inter_Arrival_mean    0.099994
# Name: 51, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min           61
# CAN_ID_Window_Count_max          100
# CAN_ID_Window_Count_mean    98.80807
# Name: 51, dtype: object
#
# CAN_ID = 68B - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.087978
# CAN_ID_Inter_Arrival_max     0.112062
# CAN_ID_Inter_Arrival_mean     0.10004
# Name: 52, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            61
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    98.771636
# Name: 52, dtype: object
#
# CAN_ID = 69F - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.997053
# CAN_ID_Inter_Arrival_max      1.00298
# CAN_ID_Inter_Arrival_mean    0.999938
# Name: 53, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min        6
# CAN_ID_Window_Count_max       10
# CAN_ID_Window_Count_mean    9.88
# Name: 53, dtype: object
#
# CAN_ID = 6FB - Normal Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     2.999766
# CAN_ID_Inter_Arrival_max     3.050461
# CAN_ID_Inter_Arrival_mean    3.014895
# Name: 54, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min           2
# CAN_ID_Window_Count_max           4
# CAN_ID_Window_Count_mean    3.32967
# Name: 54, dtype: object

# %%
# Ensure CAN_ID is treated as a string
dos_df['CAN_ID'] = dos_df['CAN_ID'].astype(str)

# Calculate statistics for each CAN_ID in DoS dataset
stats_dos = dos_df.groupby('CAN_ID').agg({
    'CAN_ID_Inter_Arrival': ['min', 'max', 'mean'],
    'CAN_ID_Window_Count': ['min', 'max', 'mean']
})

# Rename columns for clarity
stats_dos.columns = ['_'.join(col).strip() for col in stats_dos.columns.values]

# Reset index to make CAN_ID a column
stats_dos = stats_dos.reset_index()

# Ensure CAN_ID is quoted in CSV to prevent scientific notation
stats_dos['CAN_ID'] = stats_dos['CAN_ID'].apply(lambda x: f'"{x}"')

# Save to CSV with quoting
stats_dos.to_csv(os.path.join(data_dir, 'dos_can_id_statistics.csv'), index=False, quoting=csv.QUOTE_NONNUMERIC)

# Print statistics for each CAN_ID
for can_id in stats_dos.index:
    print(f"\nCAN_ID = {stats_dos.loc[can_id, 'CAN_ID'].strip('\"')} - DoS Dataset:")
    print(f"CAN_ID_Inter_Arrival:")
    print(stats_dos.loc[can_id, ['CAN_ID_Inter_Arrival_min', 'CAN_ID_Inter_Arrival_max', 'CAN_ID_Inter_Arrival_mean']])
    print(f"CAN_ID_Window_Count:")
    print(stats_dos.loc[can_id, ['CAN_ID_Window_Count_min', 'CAN_ID_Window_Count_max', 'CAN_ID_Window_Count_mean']])
# Out:
# CAN_ID = 000 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.0002
# CAN_ID_Inter_Arrival_max      0.0003
# CAN_ID_Inter_Arrival_mean    0.00025
# Name: 0, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            16012
# CAN_ID_Window_Count_max            23989
# CAN_ID_Window_Count_mean    20795.886728
# Name: 0, dtype: object
#
# CAN_ID = 090 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.001511
# CAN_ID_Inter_Arrival_max     10.010306
# CAN_ID_Inter_Arrival_mean     0.011379
# Name: 1, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            356
# CAN_ID_Window_Count_max           1000
# CAN_ID_Window_Count_mean    889.597463
# Name: 1, dtype: object
#
# CAN_ID = 0C6 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.000037
# CAN_ID_Inter_Arrival_max     10.010294
# CAN_ID_Inter_Arrival_mean     0.011379
# Name: 2, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            356
# CAN_ID_Window_Count_max           1000
# CAN_ID_Window_Count_mean    889.597463
# Name: 2, dtype: object
#
# CAN_ID = 12E - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.001384
# CAN_ID_Inter_Arrival_max     10.010303
# CAN_ID_Inter_Arrival_mean     0.011379
# Name: 3, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            356
# CAN_ID_Window_Count_max           1000
# CAN_ID_Window_Count_mean    889.597463
# Name: 3, dtype: object
#
# CAN_ID = 186 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.001838
# CAN_ID_Inter_Arrival_max     10.010615
# CAN_ID_Inter_Arrival_mean     0.011381
# Name: 4, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            356
# CAN_ID_Window_Count_max           1000
# CAN_ID_Window_Count_mean    889.416931
# Name: 4, dtype: object
#
# CAN_ID = 18A - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.001834
# CAN_ID_Inter_Arrival_max     10.010611
# CAN_ID_Inter_Arrival_mean     0.011381
# Name: 5, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            356
# CAN_ID_Window_Count_max           1000
# CAN_ID_Window_Count_mean    889.416931
# Name: 5, dtype: object
#
# CAN_ID = 1A0 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.091542
# CAN_ID_Inter_Arrival_max     10.095673
# CAN_ID_Inter_Arrival_mean     0.113902
# Name: 6, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            36
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    88.823448
# Name: 6, dtype: object
#
# CAN_ID = 1F6 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.002276
# CAN_ID_Inter_Arrival_max     10.010601
# CAN_ID_Inter_Arrival_mean     0.011381
# Name: 7, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            356
# CAN_ID_Window_Count_max           1000
# CAN_ID_Window_Count_mean    889.416655
# Name: 7, dtype: object
#
# CAN_ID = 211 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.011068
# CAN_ID_Inter_Arrival_max     10.018923
# CAN_ID_Inter_Arrival_mean     0.022755
# Name: 8, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min           178
# CAN_ID_Window_Count_max           501
# CAN_ID_Window_Count_mean    444.95204
# Name: 8, dtype: object
#
# CAN_ID = 214 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.011183
# CAN_ID_Inter_Arrival_max     10.019003
# CAN_ID_Inter_Arrival_mean     0.022755
# Name: 9, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min           178
# CAN_ID_Window_Count_max           501
# CAN_ID_Window_Count_mean    444.95204
# Name: 9, dtype: object
#
# CAN_ID = 217 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.012535
# CAN_ID_Inter_Arrival_max     10.00071
# CAN_ID_Inter_Arrival_mean     0.02276
# Name: 10, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            178
# CAN_ID_Window_Count_max            500
# CAN_ID_Window_Count_mean    444.645891
# Name: 10, dtype: object
#
# CAN_ID = 218 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.091585
# CAN_ID_Inter_Arrival_max     10.097796
# CAN_ID_Inter_Arrival_mean     0.113961
# Name: 11, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            35
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    88.958564
# Name: 11, dtype: object
#
# CAN_ID = 242 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.012134
# CAN_ID_Inter_Arrival_max     10.020564
# CAN_ID_Inter_Arrival_mean     0.022758
# Name: 12, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            178
# CAN_ID_Window_Count_max            500
# CAN_ID_Window_Count_mean    444.798732
# Name: 12, dtype: object
#
# CAN_ID = 29A - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.006306
# CAN_ID_Inter_Arrival_max     10.020202
# CAN_ID_Inter_Arrival_mean     0.022758
# Name: 13, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            178
# CAN_ID_Window_Count_max            500
# CAN_ID_Window_Count_mean    444.798732
# Name: 13, dtype: object
#
# CAN_ID = 29C - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.012383
# CAN_ID_Inter_Arrival_max     10.020699
# CAN_ID_Inter_Arrival_mean     0.022758
# Name: 14, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            178
# CAN_ID_Window_Count_max            500
# CAN_ID_Window_Count_mean    444.798732
# Name: 14, dtype: object
#
# CAN_ID = 2B7 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.006599
# CAN_ID_Inter_Arrival_max     10.020238
# CAN_ID_Inter_Arrival_mean     0.022758
# Name: 15, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            178
# CAN_ID_Window_Count_max            500
# CAN_ID_Window_Count_mean    444.798732
# Name: 15, dtype: object
#
# CAN_ID = 2C6 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.012747
# CAN_ID_Inter_Arrival_max     10.000734
# CAN_ID_Inter_Arrival_mean     0.022759
# Name: 16, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            179
# CAN_ID_Window_Count_max            500
# CAN_ID_Window_Count_mean    444.621726
# Name: 16, dtype: object
#
# CAN_ID = 303 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min       0.09194
# CAN_ID_Inter_Arrival_max     10.104102
# CAN_ID_Inter_Arrival_mean     0.113831
# Name: 17, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min       35
# CAN_ID_Window_Count_max      100
# CAN_ID_Window_Count_mean    89.0
# Name: 17, dtype: object
#
# CAN_ID = 350 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.010037
# CAN_ID_Inter_Arrival_max     10.099315
# CAN_ID_Inter_Arrival_mean     0.112561
# Name: 18, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            35
# CAN_ID_Window_Count_max           108
# CAN_ID_Window_Count_mean    90.298772
# Name: 18, dtype: object
#
# CAN_ID = 352 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.032947
# CAN_ID_Inter_Arrival_max     10.040767
# CAN_ID_Inter_Arrival_mean     0.045517
# Name: 19, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min             89
# CAN_ID_Window_Count_max            250
# CAN_ID_Window_Count_mean    222.461963
# Name: 19, dtype: object
#
# CAN_ID = 354 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.032477
# CAN_ID_Inter_Arrival_max     10.040676
# CAN_ID_Inter_Arrival_mean      0.04552
# Name: 20, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            89
# CAN_ID_Window_Count_max           250
# CAN_ID_Window_Count_mean    222.33701
# Name: 20, dtype: object
#
# CAN_ID = 392 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.042885
# CAN_ID_Inter_Arrival_max     10.05032
# CAN_ID_Inter_Arrival_mean    0.056938
# Name: 21, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min             71
# CAN_ID_Window_Count_max            200
# CAN_ID_Window_Count_mean    177.822069
# Name: 21, dtype: object
#
# CAN_ID = 3B7 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.095531
# CAN_ID_Inter_Arrival_max     10.112736
# CAN_ID_Inter_Arrival_mean      0.11456
# Name: 22, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            35
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    88.377778
# Name: 22, dtype: object
#
# CAN_ID = 3FA - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min         0.092
# CAN_ID_Inter_Arrival_max     10.104087
# CAN_ID_Inter_Arrival_mean     0.113831
# Name: 23, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min       35
# CAN_ID_Window_Count_max      100
# CAN_ID_Window_Count_mean    89.0
# Name: 23, dtype: object
#
# CAN_ID = 433 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min       0.99773
# CAN_ID_Inter_Arrival_max     11.004378
# CAN_ID_Inter_Arrival_mean      1.13934
# Name: 24, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            4
# CAN_ID_Window_Count_max           10
# CAN_ID_Window_Count_mean    8.890411
# Name: 24, dtype: object
#
# CAN_ID = 45C - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.09566
# CAN_ID_Inter_Arrival_max     10.09916
# CAN_ID_Inter_Arrival_mean    0.113943
# Name: 25, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            36
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    88.823448
# Name: 25, dtype: object
#
# CAN_ID = 4AC - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.020118
# CAN_ID_Inter_Arrival_max     10.099235
# CAN_ID_Inter_Arrival_mean     0.113629
# Name: 26, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            36
# CAN_ID_Window_Count_max           102
# CAN_ID_Window_Count_mean    89.137552
# Name: 26, dtype: object
#
# CAN_ID = 4F8 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.093383
# CAN_ID_Inter_Arrival_max     10.115529
# CAN_ID_Inter_Arrival_mean       0.1144
# Name: 27, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            35
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    88.417476
# Name: 27, dtype: object
#
# CAN_ID = 4FA - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.091799
# CAN_ID_Inter_Arrival_max     10.098787
# CAN_ID_Inter_Arrival_mean     0.113804
# Name: 28, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min       35
# CAN_ID_Window_Count_max      100
# CAN_ID_Window_Count_mean    89.0
# Name: 28, dtype: object
#
# CAN_ID = 500 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.088416
# CAN_ID_Inter_Arrival_max     10.102466
# CAN_ID_Inter_Arrival_mean     0.113808
# Name: 29, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            36
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    88.975207
# Name: 29, dtype: object
#
# CAN_ID = 511 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min       0.09449
# CAN_ID_Inter_Arrival_max     10.101721
# CAN_ID_Inter_Arrival_mean     0.113801
# Name: 30, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            36
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    88.975207
# Name: 30, dtype: object
#
# CAN_ID = 552 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.091708
# CAN_ID_Inter_Arrival_max     10.103883
# CAN_ID_Inter_Arrival_mean     0.113832
# Name: 31, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min       35
# CAN_ID_Window_Count_max      100
# CAN_ID_Window_Count_mean    89.0
# Name: 31, dtype: object
#
# CAN_ID = 55D - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.019853
# CAN_ID_Inter_Arrival_max     10.099299
# CAN_ID_Inter_Arrival_mean     0.111325
# Name: 32, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            36
# CAN_ID_Window_Count_max           105
# CAN_ID_Window_Count_mean    91.026954
# Name: 32, dtype: object
#
# CAN_ID = 563 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.091662
# CAN_ID_Inter_Arrival_max     10.095818
# CAN_ID_Inter_Arrival_mean     0.113744
# Name: 33, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            36
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    88.975207
# Name: 33, dtype: object
#
# CAN_ID = 564 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.094485
# CAN_ID_Inter_Arrival_max     10.101018
# CAN_ID_Inter_Arrival_mean     0.113961
# Name: 34, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            36
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    88.823448
# Name: 34, dtype: object
#
# CAN_ID = 575 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.092609
# CAN_ID_Inter_Arrival_max     10.103016
# CAN_ID_Inter_Arrival_mean      0.11383
# Name: 35, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            36
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    88.823448
# Name: 35, dtype: object
#
# CAN_ID = 5D7 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.086657
# CAN_ID_Inter_Arrival_max     10.100489
# CAN_ID_Inter_Arrival_mean     0.113796
# Name: 36, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            36
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    88.975207
# Name: 36, dtype: object
#
# CAN_ID = 5DA - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.094691
# CAN_ID_Inter_Arrival_max     10.101476
# CAN_ID_Inter_Arrival_mean     0.113801
# Name: 37, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            36
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    88.975207
# Name: 37, dtype: object
#
# CAN_ID = 5DE - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.019762
# CAN_ID_Inter_Arrival_max     10.099269
# CAN_ID_Inter_Arrival_mean     0.111029
# Name: 38, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min           36
# CAN_ID_Window_Count_max          110
# CAN_ID_Window_Count_mean    91.88172
# Name: 38, dtype: object
#
# CAN_ID = 5DF - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.095661
# CAN_ID_Inter_Arrival_max     10.099244
# CAN_ID_Inter_Arrival_mean      0.11394
# Name: 39, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            36
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    88.823448
# Name: 39, dtype: object
#
# CAN_ID = 5E9 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.093618
# CAN_ID_Inter_Arrival_max     10.101145
# CAN_ID_Inter_Arrival_mean     0.113863
# Name: 40, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min       35
# CAN_ID_Window_Count_max      100
# CAN_ID_Window_Count_mean    89.0
# Name: 40, dtype: object
#
# CAN_ID = 62C - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.095617
# CAN_ID_Inter_Arrival_max     10.096111
# CAN_ID_Inter_Arrival_mean     0.113744
# Name: 41, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            36
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    88.975207
# Name: 41, dtype: object
#
# CAN_ID = 634 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.095069
# CAN_ID_Inter_Arrival_max     10.106554
# CAN_ID_Inter_Arrival_mean     0.113876
# Name: 42, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            36
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    88.823448
# Name: 42, dtype: object
#
# CAN_ID = 646 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min       0.49482
# CAN_ID_Inter_Arrival_max     10.167352
# CAN_ID_Inter_Arrival_mean     0.576703
# Name: 43, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min             7
# CAN_ID_Window_Count_max            20
# CAN_ID_Window_Count_mean    17.503497
# Name: 43, dtype: object
#
# CAN_ID = 648 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.094935
# CAN_ID_Inter_Arrival_max     10.10126
# CAN_ID_Inter_Arrival_mean    0.113801
# Name: 44, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            36
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    88.975207
# Name: 44, dtype: object
#
# CAN_ID = 653 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min     0.094935
# CAN_ID_Inter_Arrival_max     10.10024
# CAN_ID_Inter_Arrival_mean    0.113809
# Name: 45, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            36
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    88.975207
# Name: 45, dtype: object
#
# CAN_ID = 657 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.090008
# CAN_ID_Inter_Arrival_max     10.099174
# CAN_ID_Inter_Arrival_mean     0.113785
# Name: 46, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            36
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    88.975207
# Name: 46, dtype: object
#
# CAN_ID = 65C - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.091886
# CAN_ID_Inter_Arrival_max     10.100393
# CAN_ID_Inter_Arrival_mean     0.113801
# Name: 47, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            36
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    88.975207
# Name: 47, dtype: object
#
# CAN_ID = 665 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      2.998141
# CAN_ID_Inter_Arrival_max     12.004611
# CAN_ID_Inter_Arrival_mean     3.376348
# Name: 48, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min        1
# CAN_ID_Window_Count_max        4
# CAN_ID_Window_Count_mean    3.08
# Name: 48, dtype: object
#
# CAN_ID = 666 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.095251
# CAN_ID_Inter_Arrival_max     10.100226
# CAN_ID_Inter_Arrival_mean     0.113814
# Name: 49, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            36
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    88.851034
# Name: 49, dtype: object
#
# CAN_ID = 66A - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min       0.09429
# CAN_ID_Inter_Arrival_max     10.101879
# CAN_ID_Inter_Arrival_mean       0.1138
# Name: 50, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            36
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    88.975207
# Name: 50, dtype: object
#
# CAN_ID = 671 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.091964
# CAN_ID_Inter_Arrival_max     10.099054
# CAN_ID_Inter_Arrival_mean     0.113804
# Name: 51, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min       35
# CAN_ID_Window_Count_max      100
# CAN_ID_Window_Count_mean    89.0
# Name: 51, dtype: object
#
# CAN_ID = 673 - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.095428
# CAN_ID_Inter_Arrival_max     10.099361
# CAN_ID_Inter_Arrival_mean     0.113786
# Name: 52, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            36
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    88.975207
# Name: 52, dtype: object
#
# CAN_ID = 68B - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min       0.09424
# CAN_ID_Inter_Arrival_max     10.102979
# CAN_ID_Inter_Arrival_mean     0.113857
# Name: 53, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            36
# CAN_ID_Window_Count_max           100
# CAN_ID_Window_Count_mean    88.823448
# Name: 53, dtype: object
#
# CAN_ID = 69F - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      0.998631
# CAN_ID_Inter_Arrival_max     10.999213
# CAN_ID_Inter_Arrival_mean     1.138813
# Name: 54, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            4
# CAN_ID_Window_Count_max           10
# CAN_ID_Window_Count_mean    8.890411
# Name: 54, dtype: object
#
# CAN_ID = 6FB - DoS Dataset:
# CAN_ID_Inter_Arrival:
# CAN_ID_Inter_Arrival_min      3.000047
# CAN_ID_Inter_Arrival_max     12.013576
# CAN_ID_Inter_Arrival_mean     3.406165
# Name: 55, dtype: object
# CAN_ID_Window_Count:
# CAN_ID_Window_Count_min            1
# CAN_ID_Window_Count_max            4
# CAN_ID_Window_Count_mean    3.083333
# Name: 55, dtype: object
